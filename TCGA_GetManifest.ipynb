# %%
import requests
import json
import pandas as pd

# %%
files_endpt = "https://api.gdc.cancer.gov/files"

# The 'fields' parameter is passed as a comma-separated string of single names.
fields = [
    "file_name",
    #"analysis.workflow_type",
    #"experimental_strategy",
    "cases.project.primary_site",
    "cases.project.disease_type",
    #"cases.project.project_id"
]

fields = ','.join(fields)

# %%
#miRNA filters
filters = {
    "op": "and",
    "content":[
        {
        "op": "in",
        "content":{
            "field": "files.data_type",
            "value": ["miRNA Expression Quantification"]
            }
        },
          {
        "op": "in",
        "content":{
               "field": "files.experimental_strategy",
                "value": ["miRNA-Seq"]
                }
        },
        {
        "op": "in",
        "content":{
            "field": "files.data_format",
            "value": ["TXT"]
            }
        },
        {
        "op": "in",
        "content":{
            "field": "cases.project.primary_site",
            "value": ["Breast", "Brain", "Kidney", "Bronchus and lung", "Thyroid gland", "Corpus uteri", "Prostate gland", "Ovary", "Stomach"]
            }
        }
        
    ]
}

# %%
# Colon filters
filters = {
    "op": "and",
    "content":[
        {
        "op": "in",
        "content":{
            "field": "files.data_type",
            "value": ["Gene Expression Quantification"]
            }
        },
        {
        "op": "in",
        "content":{
               "field": "files.analysis.workflow_type",
                "value": ["HTSeq - Counts"]
                }
        },
        {
        "op": "in",
        "content":{
            "field": "files.data_format",
            "value": ["TXT"]
            }
        },
        {
        "op": "in",
        "content":{
            "field": "cases.project.project_id",
            "value": ["TCGA-COAD"]
            }
        }
        
    ]
}

# %%
# all files RNA-seq
filters = {
    "op": "and",
    "content":[
        {
        "op": "in",
        "content":{
            "field": "files.data_type",
            "value": ["Gene Expression Quantification"]
            }
        },
        {
        "op": "in",
        "content":{
               "field": "files.analysis.workflow_type",
                "value": ["HTSeq - Counts"]
                }
        },
        {
        "op": "in",
        "content":{
            "field": "files.data_format",
            "value": ["TXT"]
            }
        },
        {
        "op": "in",
        "content":{
            "field": "cases.primary_site",
            "value": ['Hematopoietic and reticuloendothelial systems']
            }
        },
        {
        "op": "in",
        "content":{
            "field": "cases.project.program.name",
            "value": ["TCGA"]
            }
        }
        
    ]
}

# %%
'Bronchus and lung', "Thyroid gland", "Corpus uteri", "Prostate gland", "Ovary", "Stomach"

# %%
# A POST is used, so the filter parameters can be passed directly as a Dict object.
##remove manifest to have file fields
params = {
    "return_type": "manifest",
    "filters": filters,
    "fields": fields,
    "format": "TSV",
    "size": "100"
    }

# %%
# The parameters are passed to 'json' rather than 'params' in this case
response = requests.post(files_endpt, headers = {"Content-Type": "application/json"}, json = params)

print(response.content.decode("utf-8"))
# Out:
# id	filename	md5	size	state
# a2dc4c89-9ea1-4faa-b51e-914ef373f32e	fe4e1221-8143-485e-8010-87787d40fa95.htseq.counts.gz	ffa9fe4aca674478a590402f1471b24b	259750	released
# b5b95505-4b21-4db6-bf4d-1e189d0971b8	4619b035-e95d-4267-9d74-e58bdbaf5d43.htseq.counts.gz	b994c18406e8a896e04d73f952fd95c3	256538	released
# 0ecdf0e9-6a1f-42da-a42f-51bc69cc814a	6fc4ab63-6afc-4de5-a774-2ae0badb4f55.htseq.counts.gz	981f2fc401a79aea6b46f9e855185c6a	259259	released
# 58cb229f-403f-4730-a07c-2a72837d3b9c	93905cf5-5bfa-476a-9684-2b86c0062bf1.htseq.counts.gz	079b73164d7c93557a4f14633737bb1b	256717	released
# 83d32449-5b0e-4311-8cba-11a69125b314	ff2ca38e-4e16-43bc-ae35-d83bbf000fb9.htseq.counts.gz	6b28b6fcda7f20727656fd10f426fe6c	257862	released
# b5a00541-ca76-4f66-89c4-e6cc2daee774	43fceb9b-2f98-4d86-b574-7ccd5e517778.htseq.counts.gz	a631775750908767c509b644b11584d9	259385	released
# a4ebe1f0-8e8e-473d-9b1a-eceede9b18f2	118b0d94-385d-449c-a3de-bc0bf9208b7a.htseq.counts.gz	acabd51621033d7d95c9a4788344079e	256017	released
# c3c96f27-6bee-4c3c-b989-3b6cd9f79e5c	48592535-56c0-44db-9faf-700e9317854d.htseq.counts.gz	12d25e6146a3fc1fb4ca3a00e719a18c	257273	released
# 16571e35-4f63-4bb9-8c25-2ef39a6ae030	1755cecb-a97a-49f8-882f-bc53ec9a999b.htseq.counts.gz	2c9cd46ed9ba95b10bda558342ceb12c	254370	released
# aac4e708-e71e-47ea-8264-89e33f62f4f2	b5abb11d-81a9-43c8-9ad4-7a18bff5d832.htseq.counts.gz	f7a0dc57db80e88c56dd30315f296b38	262021	released
# a0dc4d65-9cdb-4380-89cf-e6277c87e951	bcae9b0e-8f2b-4b1f-b042-9a57581efb11.htseq.counts.gz	9562b41a9702a60a14ec0a47bf32411d	260974	released
# c3783122-cfe9-450a-8484-221e85286919	866db25b-6fe3-4423-9616-f603b200e188.htseq.counts.gz	f4da221b5bef7a8ee29f3b6832b3344d	257305	released

# %%
len(response.content.decode("utf-8"))
# Out:
# 13927

# %%
with open("manifest.txt","a") as manifest:
    manifest.write(response.content.decode("utf-8"))
    manifest.close()

# %% [markdown]
# ## Files

# %%
params = {
    "filters": filters,
    "fields": fields,
    "format": "TSV",
    "size": "100"
    }
response = requests.post(files_endpt, headers = {"Content-Type": "application/json"}, json = params)
with open("files.txt","a") as files:
    files.write(response.content.decode("utf-8"))
    files.close()

# %%
df_files = pd.read_csv("files.txt", sep='\t', index_col=0)
df_files.drop("id", axis=1, inplace=True)
df_files.columns=['disease_type','primary_site']
df_files.head()
# Out:
#                                                                disease_type  \
# file_name
# 1ede5c59-96ae-486b-ae1f-5f7c7909cf6a.htseq.coun...  Glioblastoma Multiforme
# 026527d4-007c-4c4e-9bd5-855c44bbe7b0.htseq.coun...  Glioblastoma Multiforme
# c8460566-8199-4a4d-93fd-67692611992d.htseq.coun...  Glioblastoma Multiforme
# 2afdb646-75ca-4bc9-9c12-30a27f994ecd.htseq.coun...  Glioblastoma Multiforme
# bcbb79d8-1d4a-4fbb-b16c-4df86839773e.htseq.coun...  Glioblastoma Multiforme
#
#                                                    primary_site
# file_name
# 1ede5c59-96ae-486b-ae1f-5f7c7909cf6a.htseq.coun...        Brain
# 026527d4-007c-4c4e-9bd5-855c44bbe7b0.htseq.coun...        Brain
# c8460566-8199-4a4d-93fd-67692611992d.htseq.coun...        Brain
# 2afdb646-75ca-4bc9-9c12-30a27f994ecd.htseq.coun...        Brain
# bcbb79d8-1d4a-4fbb-b16c-4df86839773e.htseq.coun...        Brain

# %%
df_files[df_files!="cases.0.project.primary_site"].to_csv("files.dat")

# %%
df_files.to_csv("files_new.dat", index=True, header=True)
