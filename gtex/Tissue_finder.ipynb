# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv("mainTable.csv",index_col=[0], header=[0])

# %%
df.head()
# Out:
#                  GTEX-1117F-0226-SM-5GZZ7  GTEX-111CU-1826-SM-5GZYN  \
# ENSG00000167578                     873.0                    1603.0
# ENSG00000078237                     168.0                     395.0
# ENSG00000146083                    2997.0                    3407.0
# ENSG00000158486                       0.0                       3.0
# ENSG00000198242                   12665.0                   14508.0
#
#                  GTEX-111FC-0226-SM-5N9B8  GTEX-111VG-2326-SM-5N9BK  \
# ENSG00000167578                    1432.0                    1768.0
# ENSG00000078237                     247.0                    1090.0
# ENSG00000146083                    3905.0                    3776.0
# ENSG00000158486                      13.0                      16.0
# ENSG00000198242                   23482.0                   13931.0
#
#                  GTEX-111YS-2426-SM-5GZZQ  GTEX-1122O-2026-SM-5NQ91  \
# ENSG00000167578                     918.0                    1507.0
# ...

# %%
df_files = pd.read_csv("files.dat", index_col=[0], header=None)
df_files
# Out:
#                                                             1
# 0
# GTEX-N7MS-0011-R1a                        Brain - Hippocampus
# GTEX-N7MS-0011-R2a                   Brain - Substantia nigra
# GTEX-N7MS-0011-R4a                           Brain - Amygdala
# GTEX-N7MS-0011-R5a            Brain - Caudate (basal ganglia)
# GTEX-N7MS-0011-R6a  Brain - Nucleus accumbens (basal ganglia)
# GTEX-N7MS-0011-R7a            Brain - Putamen (basal ganglia)
# GTEX-N7MS-0011-R8a                       Brain - Hypothalamus
# GTEX-N7MT-0011-R1a                        Brain - Hippocampus
# GTEX-N7MT-0011-R2a                   Brain - Substantia nigra
# GTEX-N7MT-0011-R3a   Brain - Anterior cingulate cortex (BA24)
# GTEX-N7MT-0011-R4a                           Brain - Amygdala
# GTEX-N7MT-0011-R5a            Brain - Caudate (basal ganglia)
# GTEX-N7MT-0011-R6a  Brain - Nucleus accumbens (basal ganglia)
# GTEX-N7MT-0011-R7a            Brain - Putamen (basal ganglia)
# ...

# %%
gtexfiles = []
for f in df.columns:
    try:
        tissue_label = re.search("GTEX\-[0-9A-Z]{4,5}\-[0-9]{4}\-[A-Z0-9]{2,3}",f).group(0)
        gtexfiles.append([f,df_files.loc[tissue_label,1].values[0]])
    except:
        try:
            tissue_label = re.search("GTEX\-[0-9A-Z]{4,5}\-[0-9]{4}",f).group(0)
            gtexfiles.append([f,df_files.loc[tissue_label,1].values[0]])
        except:
            pass

# %%
pd.DataFrame(data=gtexfiles).set_index(0).to_csv("files.dat", index=True, header=None)
