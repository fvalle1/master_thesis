# %% [markdown]
# # TopSBM: Topic Modeling with Stochastic Block Models

# %%
# %load_ext autoreload
# %autoreload 2

import os
import pylab as plt
# %matplotlib inline  

from sbmtm import sbmtm
import graph_tool.all as gt

import numpy as np
from matplotlib import pyplot as plt

gt.seed_rng(42) ## seed for graph-tool's random number generator --> same results

# %%
print(gt.openmp_get_num_threads())
# Out:
# 4

# %% [markdown]
# # Fitting the model

# %%
## we create an instance of the sbmtm-class
model = sbmtm()

# %%
## we can also skip the previous step by saving/loading a graph
#model.save_graph(filename = 'graph.xml.gz')
model.load_graph(filename = 'graph.xml.gz')

# %%
model.g
# Out:
# <Graph object, undirected, with 2246 vertices and 528093 edges at 0x7f6911ff00b8>

# %%
model.fit(verbose=True, B_max = 500)
#model.fit_overlap()
# Out:
#  : rejected insert 2 , dS: 2.772588722407818
#     l=0      B: 267 <- 500    shrinking 500 -> 385
#     l=0      B: 267 <- 500    B=385  niter:     1  count:    0  breaks:  0  min_S: 1626556.7  max_S: 1627812.4  S: 1626556.7  ΔS:     -1255.68  moves:    49
#     l=0      B: 267 <- 500    B=385  niter:     2  count:    0  breaks:  0  min_S: 1625794.3  max_S: 1627812.4  S: 1625794.3  ΔS:     -762.350  moves:    56
#     l=0      B: 267 <- 500    B=385  niter:     3  count:    0  breaks:  0  min_S: 1624481.9  max_S: 1627812.4  S: 1624481.9  ΔS:     -1312.46  moves:    54
#     l=0      B: 267 <- 500    B=385  niter:     4  count:    0  breaks:  0  min_S: 1624112.6  max_S: 1627812.4  S: 1624112.6  ΔS:     -369.318  moves:    29
#     l=0      B: 267 <- 500    B=385  niter:     5  count:    0  breaks:  0  min_S: 1623252.7  max_S: 1627812.4  S: 1623252.7  ΔS:     -859.855  moves:    46
#     l=0      B: 267 <- 500    B=385  niter:     6  count:    0  breaks:  0  min_S: 1622675.5  max_S: 1627812.4  S: 1622675.5  ΔS:     -577.245  moves:    38
#     l=0      B: 267 <- 500    B=385  niter:     7  count:    0  breaks:  0  min_S: 1622157.2  max_S: 1627812.4  S: 1622157.2  ΔS:     -518.221  moves:    45
#     l=0      B: 267 <- 500    B=385  niter:     8  count:    0  breaks:  0  min_S: 1621787.0  max_S: 1627812.4  S: 1621787.0  ΔS:     -370.220  moves:    25
#     l=0      B: 267 <- 500    B=385  niter:     9  count:    0  breaks:  0  min_S: 1621327.4  max_S: 1627812.4  S: 1621327.4  ΔS:     -459.632  moves:    28
#     l=0      B: 267 <- 500    B=385  niter:    10  count:    0  breaks:  0  min_S: 1620910.0  max_S: 1627812.4  S: 1620910.0  ΔS:     -417.394  moves:    33
#     l=0      B: 267 <- 500    B=385  niter:    11  count:    0  breaks:  0  min_S: 1620431.9  max_S: 1627812.4  S: 1620431.9  ΔS:     -478.104  moves:    28
#     l=0      B: 267 <- 500    B=385  niter:    12  count:    0  breaks:  0  min_S: 1619732.7  max_S: 1627812.4  S: 1619732.7  ΔS:     -699.215  moves:    31
#     l=0      B: 233 <- 267    B=233  niter:     1  count:    0  breaks:  0  min_S: 1607923.5  max_S: 1608382.2  S: 1607923.5  ΔS:     -458.693  moves:    27
#     l=0      B: 233 <- 267    B=233  niter:     2  count:    0  breaks:  0  min_S: 1607546.2  max_S: 1608382.2  S: 1607546.2  ΔS:     -377.291  moves:    32
#     l=0      B: 233 <- 267    B=233  niter:     3  count:    0  breaks:  0  min_S: 1607121.0  max_S: 1608382.2  S: 1607121.0  ΔS:     -425.156  moves:    26
#     l=0      B: 233 <- 267    B=233  niter:     4  count:    0  breaks:  0  min_S: 1606673.9  max_S: 1608382.2  S: 1606673.9  ΔS:     -447.136  moves:    22
#     l=0      B: 233 <- 267    B=233  niter:     5  count:    0  breaks:  0  min_S: 1606179.4  max_S: 1608382.2  S: 1606179.4  ΔS:     -494.498  moves:    28
#     l=0      B: 233 <- 267    B=233  niter:     6  count:    0  breaks:  0  min_S: 1605825.7  max_S: 1608382.2  S: 1605825.7  ΔS:     -353.672  moves:    18
#     l=0      B: 233 <- 267    B=233  niter:     7  count:    0  breaks:  0  min_S: 1605490.5  max_S: 1608382.2  S: 1605490.5  ΔS:     -335.203  moves:    28
#     l=0      B: 233 <- 267    B=233  niter:     8  count:    0  breaks:  0  min_S: 1605266.2  max_S: 1608382.2  S: 1605266.2  ΔS:     -224.312  moves:    17
#     l=0      B: 233 <- 267    B=233  niter:     9  count:    0  breaks:  0  min_S: 1604901.8  max_S: 1608382.2  S: 1604901.8  ΔS:     -364.359  moves:    19
#     l=0      B: 233 <- 267    B=233  niter:    10  count:    0  breaks:  0  min_S: 1604704.7  max_S: 1608382.2  S: 1604704.7  ΔS:     -197.161  moves:    24
#     l=0      B: 233 <- 267    B=233  niter:    11  count:    1  breaks:  1  min_S: 1604704.7  max_S: 1608382.2  S: 1604549.3  ΔS:     -155.386  moves:    13
#     l=0  Current bracket: (178, 212, 267) (1609438.6063209956, 1604061.9433524532, 1606466.9372134842)
#     l=0  Bisect at B = 233 with S = 1604549.285528757
#     l=0      B: 191 <- 205    shrinking 205 -> 191
#     l=0      B: 191 <- 205    B=191  niter:     1  count:    0  breaks:  0  min_S: 1608250.5  max_S: 1608446.7  S: 1608250.5  ΔS:     -196.219  moves:    18
#     l=0      B: 191 <- 205    B=191  niter:     2  count:    0  breaks:  0  min_S: 1608004.8  max_S: 1608446.7  S: 1608004.8  ΔS:     -245.659  moves:    19
#     l=0      B: 191 <- 205    B=191  niter:     3  count:    0  breaks:  0  min_S: 1607533.0  max_S: 1608446.7  S: 1607533.0  ΔS:     -471.776  moves:    26
#     l=0      B: 191 <- 205    B=191  niter:     4  count:    0  breaks:  0  min_S: 1607360.7  max_S: 1608446.7  S: 1607360.7  ΔS:     -172.286  moves:    17
#     l=0      B: 191 <- 205    B=191  niter:     5  count:    0  breaks:  0  min_S: 1607124.7  max_S: 1608446.7  S: 1607124.7  ΔS:     -236.039  moves:    20
#     l=0      B: 191 <- 205    B=191  niter:     6  count:    1  breaks:  1  min_S: 1607124.7  max_S: 1608446.7  S: 1606976.6  ΔS:     -148.083  moves:    13
#     l=0  Current bracket: (178, 212, 233) (1609438.6063209956, 1604061.9433524532, 1604549.2855287567)
#     l=0  Bisect at B = 191 with S = 1606976.614990921
#     l=0      B: 199 <- 205    shrinking 205 -> 199
#     l=0      B: 199 <- 205    B=199  niter:     1  count:    0  breaks:  0  min_S: 1606749.2  max_S: 1606994.4  S: 1606749.2  ΔS:     -245.209  moves:    17
#     l=0      B: 199 <- 205    B=199  niter:     2  count:    0  breaks:  0  min_S: 1606573.3  max_S: 1606994.4  S: 1606573.3  ΔS:     -175.928  moves:    16
#     l=0      B: 199 <- 205    B=199  niter:     3  count:    0  breaks:  0  min_S: 1606106.3  max_S: 1606994.4  S: 1606106.3  ΔS:     -467.045  moves:    24
#     l=0      B: 199 <- 205    B=199  niter:     4  count:    0  breaks:  0  min_S: 1605911.3  max_S: 1606994.4  S: 1605911.3  ΔS:     -194.927  moves:    14
#     l=0      B: 199 <- 205    B=199  niter:     5  count:    0  breaks:  0  min_S: 1605735.7  max_S: 1606994.4  S: 1605735.7  ΔS:     -175.691  moves:    15
#     l=0      B: 199 <- 205    B=199  niter:     6  count:    0  breaks:  0  min_S: 1605572.6  max_S: 1606994.4  S: 1605572.6  ΔS:     -163.038  moves:    14
#     l=0      B: 199 <- 205    B=199  niter:     7  count:    1  breaks:  1  min_S: 1605572.6  max_S: 1606994.4  S: 1605474.6  ΔS:     -98.0296  moves:    12
#     l=0  Current bracket: (191, 212, 233) (1606976.6149909212, 1604061.9433524532, 1604549.2855287567)
#     l=0  Bisect at B = 199 with S = 1605474.582470843
#     l=0      B: 220 <- 233    shrinking 233 -> 220
#     l=0      B: 220 <- 233    B=220  niter:     1  count:    0  breaks:  0  min_S: 1604777.9  max_S: 1604953.8  S: 1604777.9  ΔS:     -175.850  moves:    18
#     l=0      B: 220 <- 233    B=220  niter:     2  count:    1  breaks:  1  min_S: 1604777.9  max_S: 1604953.8  S: 1604654.6  ΔS:     -123.275  moves:    16
#     l=0  Current bracket: (199, 212, 233) (1605474.5824708426, 1604061.9433524532, 1604549.2855287567)
#     l=0  Bisect at B = 220 with S = 1604654.644395607
#     l=0      B: 204 <- 205    shrinking 205 -> 204
#     l=0      B: 204 <- 205    B=204  niter:     1  count:    0  breaks:  0  min_S: 1606645.3  max_S: 1606819.9  S: 1606645.3  ΔS:     -174.610  moves:    17
#     l=0      B: 204 <- 205    B=204  niter:     2  count:    0  breaks:  0  min_S: 1606270.2  max_S: 1606819.9  S: 1606270.2  ΔS:     -375.121  moves:    23
#     l=0      B: 204 <- 205    B=204  niter:     3  count:    0  breaks:  0  min_S: 1606062.4  max_S: 1606819.9  S: 1606062.4  ΔS:     -207.849  moves:    10
#     l=0      B: 204 <- 205    B=204  niter:     4  count:    1  breaks:  1  min_S: 1606062.4  max_S: 1606819.9  S: 1605914.5  ΔS:     -147.892  moves:    14
#     l=0  Current bracket: (199, 212, 220) (1605474.5824708426, 1604061.9433524532, 1604654.6443956073)
#     l=0  Bisect at B = 204 with S = 1605914.470884797
#     l=0      B: 207 <- 212    shrinking 212 -> 207
#     l=0      B: 207 <- 212    B=207  niter:     1  count:    0  breaks:  0  min_S: 1603655.5  max_S: 1603955.7  S: 1603655.5  ΔS:     -300.252  moves:    21
#     l=0      B: 207 <- 212    B=207  niter:     2  count:    1  breaks:  1  min_S: 1603655.5  max_S: 1603955.7  S: 1603536.1  ΔS:     -119.410  moves:    10
#     l=0  Current bracket: (204, 212, 220) (1605914.470884797, 1604061.9433524532, 1604654.6443956073)
#     l=0  Bisect at B = 207 with S = 1603536.075044202
#     l=0      B: 209 <- 212    shrinking 212 -> 209
#     l=0      B: 209 <- 212    B=209  niter:     1  count:    1  breaks:  1  min_S: 1604008.0  max_S: 1604008.0  S: 1603938.7  ΔS:     -69.3295  moves:    11
#     l=0  Current bracket: (204, 207, 212) (1605914.470884797, 1603536.075044202, 1604061.9433524532)
#     l=0  Bisect at B = 209 with S = 1603938.708720549
#     l=0  Current bracket: (204, 207, 209) (1605914.470884797, 1603536.075044202, 1603938.7087205492)
#     l=0  Bisect at B = 205 with S = 1606981.821572995
#     l=0      B: 206 <- 207    shrinking 207 -> 206
#     l=0      B: 206 <- 207    B=206  niter:     1  count:    1  breaks:  1  min_S: 1603484.5  max_S: 1603484.5  S: 1603386.8  ΔS:     -97.7067  moves:     9
#     l=0  Current bracket: (205, 207, 209) (1606981.8215729948, 1603536.075044202, 1603938.7087205492)
#     l=0  Bisect at B = 206 with S = 1603386.842902796
#     l=0  Current bracket: (205, 206, 207) (1606981.8215729948, 1603386.8429027959, 1603536.075044202)
#     l=0  Bisect at B = 205 with S = 1606981.821572995
#     l=0  Best result: B = 206, S = 1603386.842902796
# level 0 : replaced (2246, 2) -> (2246, 206) , dS: -65846.42692544218 2
#     l=1      B: 117 <- 206    shrinking 206 -> 158
#     l=1      B: 117 <- 206    B=158  niter:     1  count:    0  breaks:  0  min_S: 58886.003  max_S: 58966.135  S: 58886.003  ΔS:     -80.1317  moves:    10
#     l=1      B: 117 <- 206    B=158  niter:     2  count:    0  breaks:  0  min_S: 58813.996  max_S: 58966.135  S: 58813.996  ΔS:     -72.0070  moves:     7
#     l=1      B: 117 <- 206    B=158  niter:     3  count:    0  breaks:  0  min_S: 58803.914  max_S: 58966.135  S: 58803.914  ΔS:     -10.0822  moves:     3
#     l=1      B: 117 <- 206    B=158  niter:     4  count:    0  breaks:  0  min_S: 58741.312  max_S: 58966.135  S: 58741.312  ΔS:     -62.6022  moves:    10
#     l=1      B: 117 <- 206    B=158  niter:     5  count:    1  breaks:  1  min_S: 58741.312  max_S: 58966.135  S: 58741.312  ΔS:      0.00000  moves:     0
#     l=1      B: 117 <- 206    shrinking 158 -> 122
#     l=1      B: 117 <- 206    B=122  niter:     1  count:    0  breaks:  0  min_S: 56863.676  max_S: 56905.426  S: 56863.676  ΔS:     -41.7507  moves:    12
#     l=1      B: 62 <- 117    B=90  niter:     5  count:    0  breaks:  0  min_S: 55467.537  max_S: 55607.612  S: 55467.537  ΔS:     -11.3338  moves:     4
#     l=1      B: 62 <- 117    B=90  niter:     6  count:    1  breaks:  1  min_S: 55467.537  max_S: 55607.612  S: 55464.717  ΔS:     -2.81957  moves:     4
#     l=1      B: 62 <- 117    shrinking 90 -> 69
#     l=1      B: 62 <- 117    B=69  niter:     1  count:    0  breaks:  0  min_S: 55065.751  max_S: 55081.947  S: 55065.751  ΔS:     -16.1959  moves:     8
#     l=1      B: 62 <- 117    B=69  niter:     2  count:    0  breaks:  0  min_S: 55040.650  max_S: 55081.947  S: 55040.650  ΔS:     -25.1009  moves:    11
#     l=1      B: 62 <- 117    B=69  niter:     3  count:    0  breaks:  0  min_S: 55031.172  max_S: 55081.947  S: 55031.172  ΔS:     -9.47773  moves:     5
#     l=1      B: 62 <- 117    B=69  niter:     4  count:    0  breaks:  0  min_S: 55004.341  max_S: 55081.947  S: 55004.341  ΔS:     -26.8307  moves:     9
#     l=1      B: 62 <- 117    B=69  niter:     5  count:    0  breaks:  0  min_S: 54988.151  max_S: 55081.947  S: 54988.151  ΔS:     -16.1904  moves:     9
#     l=1      B: 62 <- 117    B=69  niter:     6  count:    0  breaks:  0  min_S: 54981.246  max_S: 55081.947  S: 54981.246  ΔS:     -6.90532  moves:     7
#     l=1      B: 62 <- 117    B=69  niter:     7  count:    1  breaks:  1  min_S: 54981.246  max_S: 55081.947  S: 54979.519  ΔS:     -1.72670  moves:     3
#     l=1      B: 62 <- 117    shrinking 69 -> 62
#     l=1      B: 62 <- 117    B=62  niter:     1  count:    0  breaks:  0  min_S: 54861.222  max_S: 54869.612  S: 54861.222  ΔS:     -8.39076  moves:     4
#     l=1      B: 62 <- 117    B=62  niter:     2  count:    0  breaks:  0  min_S: 54855.683  max_S: 54869.612  S: 54855.683  ΔS:     -5.53841  moves:     6
#     l=1      B: 62 <- 117    B=62  niter:     3  count:    1  breaks:  1  min_S: 54855.683  max_S: 54869.612  S: 54850.279  ΔS:     -5.40452  moves:     5
#     l=1  Current bracket: (2, 117, 206) (63264.45593687323, 56404.72407096763, 64044.658958354295)
#     l=1  Bisect at B = 62 with S = 54850.27867289235
#     l=1      B: 28 <- 62    shrinking 62 -> 48
#     l=1      B: 28 <- 62    B=48  niter:     1  count:    0  breaks:  0  min_S: 54663.446  max_S: 54673.091  S: 54663.446  ΔS:     -9.64587  moves:     6
#     l=1      B: 28 <- 62    B=48  niter:     2  count:    1  breaks:  1  min_S: 54663.446  max_S: 54673.091  S: 54658.680  ΔS:     -4.76565  moves:     4
#     l=1      B: 28 <- 62    shrinking 48 -> 37
#     l=1      B: 28 <- 62    B=37  niter:     1  count:    1  breaks:  1  min_S: 54523.696  max_S: 54523.696  S: 54519.990  ΔS:     -3.70553  moves:     6
#     l=1      B: 28 <- 62    shrinking 37 -> 28
#     l=1      B: 28 <- 62    B=28  niter:     1  count:    0  breaks:  0  min_S: 54378.139  max_S: 54391.497  S: 54378.139  ΔS:     -13.3582  moves:     6
#     l=1      B: 28 <- 62    B=28  niter:     2  count:    0  breaks:  0  min_S: 54363.068  max_S: 54391.497  S: 54363.068  ΔS:     -15.0712  moves:    10
#     l=1      B: 28 <- 62    B=28  niter:     3  count:    1  breaks:  1  min_S: 54363.068  max_S: 54391.497  S: 54360.240  ΔS:     -2.82708  moves:     3
#     l=1  Current bracket: (2, 62, 117) (63264.45593687323, 54850.27867289235, 56404.72407096763)
#     l=1  Bisect at B = 28 with S = 54360.24048350154
#     l=1      B: 41 <- 48    shrinking 48 -> 41
#     l=1      B: 41 <- 48    B=41  niter:     1  count:    1  breaks:  1  min_S: 54571.482  max_S: 54571.482  S: 54569.697  ΔS:     -1.78524  moves:     4
#     l=1  Current bracket: (2, 28, 62) (63264.45593687323, 54360.24048350154, 54850.27867289235)
#     l=1  Bisect at B = 41 with S = 54569.69655783338
#     l=1      B: 15 <- 28    shrinking 28 -> 22
#     l=1      B: 15 <- 28    B=22  niter:     1  count:    0  breaks:  0  min_S: 54271.709  max_S: 54281.025  S: 54271.709  ΔS:     -9.31590  moves:     5
#     l=1      B: 15 <- 28    B=22  niter:     2  count:    0  breaks:  0  min_S: 54265.092  max_S: 54281.025  S: 54265.092  ΔS:     -6.61730  moves:     2
#     l=1      B: 15 <- 28    B=22  niter:     3  count:    1  breaks:  1  min_S: 54265.092  max_S: 54281.025  S: 54262.635  ΔS:     -2.45718  moves:     2
#     l=1      B: 15 <- 28    shrinking 22 -> 17
#     l=1      B: 15 <- 28    B=17  niter:     1  count:    1  breaks:  1  min_S: 54212.618  max_S: 54212.618  S: 54210.199  ΔS:     -2.41951  moves:     4
#     l=1      B: 15 <- 28    shrinking 17 -> 15
#     l=1      B: 15 <- 28    B=15  niter:     1  count:    0  breaks:  0  min_S: 54192.772  max_S: 54198.528  S: 54192.772  ΔS:     -5.75570  moves:     4
#     l=1      B: 15 <- 28    B=15  niter:     2  count:    1  breaks:  1  min_S: 54192.772  max_S: 54198.528  S: 54188.921  ΔS:     -3.85046  moves:     1
#     l=1  Current bracket: (2, 28, 41) (63264.45593687323, 54360.24048350154, 54569.69655783338)
#     l=1  Bisect at B = 15 with S = 54188.92147165614
#     l=1      B: 7 <- 15    shrinking 15 -> 12
#     l=1      B: 7 <- 15    B=12  niter:     1  count:    0  breaks:  0  min_S: 54225.789  max_S: 54233.930  S: 54225.789  ΔS:     -8.14073  moves:     3
#     l=1      B: 7 <- 15    B=12  niter:     2  count:    1  breaks:  1  min_S: 54225.789  max_S: 54233.930  S: 54222.650  ΔS:     -3.13900  moves:     1
#     l=1      B: 7 <- 15    shrinking 12 -> 9
#     l=1      B: 7 <- 15    B=9  niter:     1  count:    0  breaks:  0  min_S: 54359.162  max_S: 54367.048  S: 54359.162  ΔS:     -7.88583  moves:     3
#     l=1      B: 7 <- 15    B=9  niter:     2  count:    1  breaks:  1  min_S: 54359.162  max_S: 54367.048  S: 54354.762  ΔS:     -4.40014  moves:     2
#     l=1      B: 7 <- 15    shrinking 9 -> 7
#     l=1      B: 7 <- 15    B=7  niter:     1  count:    0  breaks:  0  min_S: 54599.522  max_S: 54664.665  S: 54599.522  ΔS:     -65.1431  moves:    11
#     l=1      B: 7 <- 15    B=7  niter:     2  count:    1  breaks:  1  min_S: 54599.522  max_S: 54664.665  S: 54596.185  ΔS:     -3.33709  moves:     2
#     l=1  Current bracket: (2, 15, 28) (63264.45593687323, 54188.92147165614, 54360.24048350154)
#     l=1  Bisect at B = 7 with S = 54596.18467566219
#     l=1      B: 20 <- 22    shrinking 22 -> 20
#     l=1      B: 20 <- 22    B=20  niter:     1  count:    1  breaks:  1  min_S: 54236.474  max_S: 54236.474  S: 54235.849  ΔS:    -0.625627  moves:     1
#     l=1  Current bracket: (7, 15, 28) (54596.18467566219, 54188.92147165614, 54360.24048350154)
#     l=1  Bisect at B = 20 with S = 54235.84856404053
#     l=1      B: 10 <- 12    shrinking 12 -> 10
#     l=1      B: 10 <- 12    B=10  niter:     1  count:    0  breaks:  0  min_S: 54299.843  max_S: 54313.055  S: 54299.843  ΔS:     -13.2118  moves:     4
#     l=1      B: 10 <- 12    B=10  niter:     2  count:    1  breaks:  1  min_S: 54299.843  max_S: 54313.055  S: 54299.670  ΔS:    -0.172550  moves:     1
#     l=1  Current bracket: (7, 15, 20) (54596.18467566219, 54188.92147165614, 54235.848564040534)
#     l=1  Bisect at B = 10 with S = 54299.67018879314
#     l=1  Current bracket: (10, 15, 20) (54299.67018879314, 54188.92147165614, 54235.848564040534)
#     l=1  Bisect at B = 12 with S = 54222.64998795344
#     l=1  Current bracket: (12, 15, 20) (54222.64998795344, 54188.92147165614, 54235.848564040534)
#     l=1  Bisect at B = 17 with S = 54210.19873878425
#     l=1      B: 13 <- 15    shrinking 15 -> 13
#     l=1      B: 13 <- 15    B=13  niter:     1  count:    0  breaks:  0  min_S: 54224.993  max_S: 54241.162  S: 54224.993  ΔS:     -16.1686  moves:     7
#     l=1      B: 13 <- 15    B=13  niter:     2  count:    0  breaks:  0  min_S: 54218.582  max_S: 54241.162  S: 54218.582  ΔS:     -6.41078  moves:     4
#     l=1      B: 13 <- 15    B=13  niter:     3  count:    0  breaks:  0  min_S: 54212.400  max_S: 54241.162  S: 54212.400  ΔS:     -6.18178  moves:     3
#     l=1      B: 13 <- 15    B=13  niter:     4  count:    1  breaks:  1  min_S: 54212.400  max_S: 54241.162  S: 54212.400  ΔS:      0.00000  moves:     0
#     l=1  Current bracket: (12, 15, 17) (54222.64998795344, 54188.92147165614, 54210.198738784246)
#     l=1  Bisect at B = 13 with S = 54212.40043537227
#     l=1      B: 14 <- 15    shrinking 15 -> 14
#     l=1      B: 14 <- 15    B=14  niter:     1  count:    0  breaks:  0  min_S: 54194.723  max_S: 54214.096  S: 54194.723  ΔS:     -19.3734  moves:     7
#     l=1      B: 14 <- 15    B=14  niter:     2  count:    0  breaks:  0  min_S: 54159.765  max_S: 54214.096  S: 54159.765  ΔS:     -34.9574  moves:     2
#     l=1      B: 14 <- 15    B=14  niter:     3  count:    0  breaks:  0  min_S: 54154.097  max_S: 54214.096  S: 54154.097  ΔS:     -5.66796  moves:     1
#     l=1      B: 14 <- 15    B=14  niter:     4  count:    1  breaks:  1  min_S: 54154.097  max_S: 54214.096  S: 54150.767  ΔS:     -3.33055  moves:     3
#     l=1  Current bracket: (13, 15, 17) (54212.40043537227, 54188.92147165614, 54210.198738784246)
#     l=1  Bisect at B = 14 with S = 54150.76692482013
#     l=1  Current bracket: (13, 14, 15) (54212.40043537227, 54150.766924820135, 54188.92147165614)
#     l=1  Bisect at B = 13 with S = 54212.40043537227
#     l=1  Best result: B = 14, S = 54150.76692482013
# level 1 : replaced (206, 1) -> (206, 14) , dS: -76553.79621856147 3
#     l=2      B: 9 <- 14    shrinking 14 -> 11
#     l=2      B: 9 <- 14    B=11  niter:     1  count:    1  breaks:  1  min_S: 575.26416  max_S: 575.26416  S: 575.26416  ΔS:      0.00000  moves:     0
#     l=2      B: 9 <- 14    shrinking 11 -> 9
#     l=2      B: 9 <- 14    B=9  niter:     1  count:    1  breaks:  1  min_S: 573.66261  max_S: 573.66261  S: 573.66261  ΔS:      0.00000  moves:     0
#     l=2  Current bracket: (2, 9, 14) (573.5055272956849, 573.6626062020046, 594.9015090083186)
#     l=2      B: 6 <- 9    shrinking 9 -> 7
#     l=2      B: 6 <- 9    B=7  niter:     1  count:    1  breaks:  1  min_S: 572.52933  max_S: 572.52933  S: 572.52933  ΔS:      0.00000  moves:     0
#     l=2      B: 6 <- 9    shrinking 7 -> 6
#     l=2      B: 6 <- 9    B=6  niter:     1  count:    0  breaks:  0  min_S: 571.62149  max_S: 571.76952  S: 571.62149  ΔS:    -0.148037  moves:     1
#     l=2      B: 6 <- 9    B=6  niter:     2  count:    0  breaks:  0  min_S: 571.38008  max_S: 571.76952  S: 571.38008  ΔS:    -0.241404  moves:     1
#     l=2      B: 6 <- 9    B=6  niter:     3  count:    1  breaks:  1  min_S: 571.38008  max_S: 571.76952  S: 571.38008  ΔS:      0.00000  moves:     0
#     l=2  Current bracket: (2, 6, 9) (573.5055272956849, 571.3800834804549, 573.6626062020046)
#     l=2      B: 4 <- 6    shrinking 6 -> 5
#     l=2      B: 4 <- 6    B=5  niter:     1  count:    1  breaks:  1  min_S: 568.75721  max_S: 568.75721  S: 568.75721  ΔS:      0.00000  moves:     0
#     l=2      B: 4 <- 6    shrinking 5 -> 4
#     l=2      B: 4 <- 6    B=4  niter:     1  count:    1  breaks:  1  min_S: 566.09582  max_S: 566.09582  S: 566.09582  ΔS:      0.00000  moves:     0
#     l=2  Current bracket: (2, 6, 9) (573.5055272956849, 571.3800834804549, 573.6626062020046)
#     l=2  Bisect at B = 4 with S = 566.0958209526947
#     l=2      B: 3 <- 4    shrinking 4 -> 3
#     l=2      B: 3 <- 4    B=3  niter:     1  count:    1  breaks:  1  min_S: 566.25149  max_S: 566.25149  S: 566.25149  ΔS:      0.00000  moves:     0
#     l=2  Current bracket: (2, 4, 6) (573.5055272956849, 566.0958209526947, 571.3800834804549)
#     l=2  Bisect at B = 3 with S = 566.251489812941
#     l=2  Current bracket: (3, 4, 6) (566.251489812941, 566.0958209526947, 571.3800834804549)
#     l=2  Bisect at B = 5 with S = 568.7572071607176
#     l=2  Current bracket: (3, 4, 5) (566.251489812941, 566.0958209526947, 568.7572071607176)
#     l=2  Bisect at B = 3 with S = 566.251489812941
#     l=2  Best result: B = 4, S = 566.0958209526947
# level 2 : replaced (14, 1) -> (14, 4) , dS: -564.1560433998238 4
#     l=3      B: 3 <- 4    shrinking 4 -> 3
#     l=3      B: 3 <- 4    B=3  niter:     1  count:    1  breaks:  1  min_S: 61.656787  max_S: 61.656787  S: 61.656787  ΔS:      0.00000  moves:     0
#     l=3  Current bracket: (2, 3, 4) (60.208755626150904, 61.656786682420886, 63.099127384047065)
#     l=3  Current bracket: (2, 2, 3) (60.208755626150904, 60.208755626150904, 61.656786682420886)
#     l=3  Bisect at B = 2 with S = 60.2087556261509
#     l=3  Best result: B = 2, S = 60.2087556261509
# level 3 : replaced (4, 1) -> (4, 2) , dS: -64.20502250548452 5
#     l=4  Current bracket: (2, 2, 2) (29.555071668741395, 29.555071668741395, 29.555071668741395)
#     l=4  Current bracket: (2, 2, 2) (29.555071668741395, 29.555071668741395, 29.555071668741395)
#     l=4  Bisect at B = 2 with S = 29.55507166874139
#     l=4  Best result: B = 2, S = 29.55507166874139
# level 4 : rejected replacement (2, 1) -> (2, 2) , dS: 0.0
#     l=4  Current bracket: (2, 2, 2) (29.555071668741395, 29.555071668741395, 29.555071668741395)
#     l=4  Current bracket: (2, 2, 2) (29.555071668741395, 29.555071668741395, 29.555071668741395)
#     l=4  Bisect at B = 2 with S = 29.55507166874139
#     l=4  Best result: B = 2, S = 29.55507166874139
# level 4 : rejected insert 2 , dS: 0.0
# level 3 : skipping 2
#     l=2      B: 9 <- 14    shrinking 14 -> 11
#     l=2      B: 9 <- 14    B=11  niter:     1  count:    0  breaks:  0  min_S: 545.70909  max_S: 550.15987  S: 545.70909  ΔS:     -4.45078  moves:     1
#     l=2      B: 9 <- 14    B=11  niter:     2  count:    1  breaks:  1  min_S: 545.70909  max_S: 550.15987  S: 545.70909  ΔS:      0.00000  moves:     0
#     l=2      B: 9 <- 14    shrinking 11 -> 9
#     l=2      B: 9 <- 14    B=9  niter:     1  count:    1  breaks:  1  min_S: 544.10753  max_S: 544.10753  S: 544.10753  ΔS:      0.00000  moves:     0
#     l=2  Current bracket: (2, 9, 14) (543.9504556269435, 544.1075345332631, 565.3464373395773)
#     l=2      B: 6 <- 9    shrinking 9 -> 7
#     l=2      B: 6 <- 9    B=7  niter:     1  count:    1  breaks:  1  min_S: 542.97426  max_S: 542.97426  S: 542.97426  ΔS:      0.00000  moves:     0
#     l=2      B: 6 <- 9    shrinking 7 -> 6
#     l=2      B: 6 <- 9    B=6  niter:     1  count:    0  breaks:  0  min_S: 542.06642  max_S: 542.21445  S: 542.06642  ΔS:    -0.148037  moves:     1
#     l=2      B: 6 <- 9    B=6  niter:     2  count:    0  breaks:  0  min_S: 541.82501  max_S: 542.21445  S: 541.82501  ΔS:    -0.241404  moves:     1
#     l=2      B: 6 <- 9    B=6  niter:     3  count:    1  breaks:  1  min_S: 541.82501  max_S: 542.21445  S: 541.82501  ΔS:      0.00000  moves:     0
#     l=2  Current bracket: (2, 6, 9) (543.9504556269435, 541.8250118117135, 544.1075345332631)
#     l=2      B: 4 <- 6    shrinking 6 -> 5
#     l=2      B: 4 <- 6    B=5  niter:     1  count:    1  breaks:  1  min_S: 539.20214  max_S: 539.20214  S: 539.20214  ΔS:      0.00000  moves:     0
#     l=2      B: 4 <- 6    shrinking 5 -> 4
#     l=2      B: 4 <- 6    B=4  niter:     1  count:    1  breaks:  1  min_S: 536.54075  max_S: 536.54075  S: 536.54075  ΔS:      0.00000  moves:     0
#     l=2  Current bracket: (2, 6, 9) (543.9504556269435, 541.8250118117135, 544.1075345332631)
#     l=2  Bisect at B = 4 with S = 536.5407492839533
#     l=2      B: 3 <- 4    shrinking 4 -> 3
#     l=2      B: 3 <- 4    B=3  niter:     1  count:    1  breaks:  1  min_S: 536.69642  max_S: 536.69642  S: 536.69642  ΔS:      0.00000  moves:     0
#     l=2  Current bracket: (2, 4, 6) (543.9504556269435, 536.5407492839533, 541.8250118117135)
#     l=2  Bisect at B = 3 with S = 536.6964181441996
#     l=2  Current bracket: (3, 4, 6) (536.6964181441996, 536.5407492839533, 541.8250118117135)
#     l=2  Bisect at B = 5 with S = 539.2021354919762
#     l=2  Current bracket: (3, 4, 5) (536.6964181441996, 536.5407492839533, 539.2021354919762)
#     l=2  Bisect at B = 3 with S = 536.6964181441996
#     l=2  Best result: B = 4, S = 536.5407492839533
# level 2 : rejected replacement (14, 4) -> (14, 4) , dS: 0.0
#     l=2      B: 9 <- 14    shrinking 14 -> 11
#     l=2      B: 9 <- 14    B=11  niter:     1  count:    1  breaks:  1  min_S: 545.70909  max_S: 545.70909  S: 545.70909  ΔS:      0.00000  moves:     0
#     l=2      B: 9 <- 14    shrinking 11 -> 9
#     l=2      B: 9 <- 14    B=9  niter:     1  count:    1  breaks:  1  min_S: 544.10753  max_S: 544.10753  S: 544.10753  ΔS:      0.00000  moves:     0
#     l=2  Current bracket: (2, 9, 14) (543.9504556269435, 544.1075345332631, 565.3464373395773)
#     l=2      B: 6 <- 9    shrinking 9 -> 7
#     l=2      B: 6 <- 9    B=7  niter:     1  count:    1  breaks:  1  min_S: 542.97426  max_S: 542.97426  S: 542.97426  ΔS:      0.00000  moves:     0
#     l=2      B: 6 <- 9    shrinking 7 -> 6
#     l=2      B: 6 <- 9    B=6  niter:     1  count:    0  breaks:  0  min_S: 541.82501  max_S: 542.21445  S: 541.82501  ΔS:    -0.389441  moves:     2
#     l=2      B: 6 <- 9    B=6  niter:     2  count:    1  breaks:  1  min_S: 541.82501  max_S: 542.21445  S: 541.82501  ΔS:      0.00000  moves:     0
#     l=2  Current bracket: (2, 6, 9) (543.9504556269435, 541.8250118117135, 544.1075345332631)
#     l=2      B: 4 <- 6    shrinking 6 -> 5
#     l=2      B: 4 <- 6    B=5  niter:     1  count:    1  breaks:  1  min_S: 539.20214  max_S: 539.20214  S: 539.20214  ΔS:      0.00000  moves:     0
#     l=2      B: 4 <- 6    shrinking 5 -> 4
#     l=2      B: 4 <- 6    B=4  niter:     1  count:    1  breaks:  1  min_S: 536.54075  max_S: 536.54075  S: 536.54075  ΔS:      0.00000  moves:     0
#     l=2  Current bracket: (2, 6, 9) (543.9504556269435, 541.8250118117135, 544.1075345332631)
#     l=2  Bisect at B = 4 with S = 536.5407492839533
#     l=2      B: 3 <- 4    shrinking 4 -> 3
#     l=2      B: 3 <- 4    B=3  niter:     1  count:    1  breaks:  1  min_S: 536.69642  max_S: 536.69642  S: 536.69642  ΔS:      0.00000  moves:     0
#     l=2  Current bracket: (2, 4, 6) (543.9504556269435, 536.5407492839533, 541.8250118117135)
#     l=2  Bisect at B = 3 with S = 536.6964181441996
#     l=2  Current bracket: (3, 4, 6) (536.6964181441996, 536.5407492839533, 541.8250118117135)
#     l=2  Bisect at B = 5 with S = 539.2021354919762
#     l=2  Current bracket: (3, 4, 5) (536.6964181441996, 536.5407492839533, 539.2021354919762)
#     l=2  Bisect at B = 3 with S = 536.6964181441996
#     l=2  Best result: B = 4, S = 536.5407492839533
# level 2 : rejected insert 14 , dS: 21.395981712732464
#     l=1      B: 117 <- 206    shrinking 206 -> 158
#     l=1      B: 117 <- 206    B=158  niter:     1  count:    0  breaks:  0  min_S: 55623.102  max_S: 55691.099  S: 55623.102  ΔS:     -67.9968  moves:     8
#     l=1      B: 117 <- 206    B=158  niter:     2  count:    0  breaks:  0  min_S: 55606.332  max_S: 55691.099  S: 55606.332  ΔS:     -16.7704  moves:     3
#     l=1      B: 117 <- 206    B=158  niter:     3  count:    0  breaks:  0  min_S: 55565.380  max_S: 55691.099  S: 55565.380  ΔS:     -40.9522  moves:     7
#     l=1      B: 117 <- 206    B=158  niter:     4  count:    0  breaks:  0  min_S: 55553.247  max_S: 55691.099  S: 55553.247  ΔS:     -12.1329  moves:     3
#     l=1      B: 117 <- 206    B=158  niter:     5  count:    0  breaks:  0  min_S: 55546.720  max_S: 55691.099  S: 55546.720  ΔS:     -6.52655  moves:     3
#     l=1      B: 117 <- 206    B=158  niter:     6  count:    1  breaks:  1  min_S: 55546.720  max_S: 55691.099  S: 55542.981  ΔS:     -3.73907  moves:     2
#     l=1      B: 117 <- 206    shrinking 158 -> 122
#     l=1      B: 117 <- 206    B=122  niter:     1  count:    0  breaks:  0  min_S: 55240.728  max_S: 55287.391  S: 55240.728  ΔS:     -46.6630  moves:    13
#     l=1      B: 117 <- 206    B=122  niter:     2  count:    0  breaks:  0  min_S: 55231.469  max_S: 55287.391  S: 55231.469  ΔS:     -9.25971  moves:     5
#     l=1      B: 117 <- 206    B=122  niter:     3  count:    0  breaks:  0  min_S: 55200.057  max_S: 55287.391  S: 55200.057  ΔS:     -31.4116  moves:     9
#     l=1      B: 117 <- 206    B=122  niter:     4  count:    1  breaks:  1  min_S: 55200.057  max_S: 55287.391  S: 55199.183  ΔS:    -0.873673  moves:     2
#     l=1      B: 117 <- 206    shrinking 122 -> 117
#     l=1      B: 117 <- 206    B=117  niter:     1  count:    1  breaks:  1  min_S: 55116.190  max_S: 55116.190  S: 55111.363  ΔS:     -4.82690  moves:     2
#     l=1  Current bracket: (4, 117, 206) (56445.03486156201, 55111.36323272361, 57222.34751128518)
#     l=0      B: 301 <- 356    B=301  niter:     3  count:    0  breaks:  0  min_S: 1595515.6  max_S: 1596340.3  S: 1595515.6  ΔS:     -323.328  moves:    11
#     l=0      B: 301 <- 356    B=301  niter:     4  count:    0  breaks:  0  min_S: 1595261.5  max_S: 1596340.3  S: 1595261.5  ΔS:     -254.052  moves:    10
#     l=0      B: 301 <- 356    B=301  niter:     5  count:    0  breaks:  0  min_S: 1594933.7  max_S: 1596340.3  S: 1594933.7  ΔS:     -327.792  moves:     9
#     l=0      B: 301 <- 356    B=301  niter:     6  count:    0  breaks:  0  min_S: 1594457.9  max_S: 1596340.3  S: 1594457.9  ΔS:     -475.855  moves:    16
#     l=0      B: 301 <- 356    B=301  niter:     7  count:    0  breaks:  0  min_S: 1594168.8  max_S: 1596340.3  S: 1594168.8  ΔS:     -289.017  moves:    13
#     l=0      B: 301 <- 356    B=301  niter:     8  count:    0  breaks:  0  min_S: 1593918.1  max_S: 1596340.3  S: 1593918.1  ΔS:     -250.707  moves:    11
#     l=0      B: 301 <- 356    B=301  niter:     9  count:    0  breaks:  0  min_S: 1593718.8  max_S: 1596340.3  S: 1593718.8  ΔS:     -199.323  moves:    11
#     l=0      B: 301 <- 356    B=301  niter:    10  count:    0  breaks:  0  min_S: 1593443.6  max_S: 1596340.3  S: 1593443.6  ΔS:     -275.254  moves:    12
#     l=0      B: 301 <- 356    B=301  niter:    11  count:    0  breaks:  0  min_S: 1593192.1  max_S: 1596340.3  S: 1593192.1  ΔS:     -251.492  moves:    15
#     l=0      B: 301 <- 356    B=301  niter:    12  count:    1  breaks:  1  min_S: 1593192.1  max_S: 1596340.3  S: 1593123.0  ΔS:     -69.0635  moves:     5
#     l=0  Current bracket: (267, 356, 411) (1597138.9823520638, 1591193.8167312122, 1591365.3567566278)
#     l=0  Bisect at B = 301 with S = 1593122.997028454
#     l=0      B: 322 <- 356    shrinking 356 -> 322
#     l=0      B: 322 <- 356    B=322  niter:     1  count:    1  breaks:  1  min_S: 1591457.4  max_S: 1591457.4  S: 1591337.0  ΔS:     -120.313  moves:     9
#     l=0  Current bracket: (301, 356, 411) (1593122.9970284537, 1591193.8167312122, 1591365.3567566278)
#     l=0  Bisect at B = 322 with S = 1591337.048628113
#     l=0      B: 377 <- 385    shrinking 385 -> 377
#     l=0      B: 377 <- 385    B=377  niter:     1  count:    0  breaks:  0  min_S: 1593114.8  max_S: 1593278.5  S: 1593114.8  ΔS:     -163.692  moves:    10
#     l=0      B: 377 <- 385    B=377  niter:     2  count:    0  breaks:  0  min_S: 1592608.6  max_S: 1593278.5  S: 1592608.6  ΔS:     -506.160  moves:    19
#     l=0      B: 377 <- 385    B=377  niter:     3  count:    0  breaks:  0  min_S: 1592241.2  max_S: 1593278.5  S: 1592241.2  ΔS:     -367.439  moves:    16
#     l=0      B: 377 <- 385    B=377  niter:     4  count:    1  breaks:  1  min_S: 1592241.2  max_S: 1593278.5  S: 1592143.4  ΔS:     -97.7921  moves:    11
#     l=0  Current bracket: (322, 356, 411) (1591337.0486281135, 1591193.8167312122, 1591365.3567566278)
#     l=0  Bisect at B = 377 with S = 1592143.375802359
#     l=0      B: 335 <- 356    shrinking 356 -> 335
#     l=0      B: 335 <- 356    B=335  niter:     1  count:    0  breaks:  0  min_S: 1590472.4  max_S: 1590816.6  S: 1590472.4  ΔS:     -344.241  moves:    13
#     l=0      B: 335 <- 356    B=335  niter:     2  count:    0  breaks:  0  min_S: 1590067.9  max_S: 1590816.6  S: 1590067.9  ΔS:     -404.523  moves:    12
#     l=0      B: 335 <- 356    B=335  niter:     3  count:    1  breaks:  1  min_S: 1590067.9  max_S: 1590816.6  S: 1589941.1  ΔS:     -126.768  moves:    11
#     l=0  Current bracket: (322, 356, 377) (1591337.0486281135, 1591193.8167312122, 1592143.375802359)
#     l=0  Bisect at B = 335 with S = 1589941.11824516
#     l=0      B: 343 <- 356    shrinking 356 -> 343
#     l=0      B: 343 <- 356    B=343  niter:     1  count:    0  breaks:  0  min_S: 1589603.4  max_S: 1589983.5  S: 1589603.4  ΔS:     -380.123  moves:    12
#     l=0      B: 343 <- 356    B=343  niter:     2  count:    1  breaks:  1  min_S: 1589603.4  max_S: 1589983.5  S: 1589452.2  ΔS:     -151.200  moves:     7
#     l=0  Current bracket: (322, 335, 356) (1591337.0486281135, 1589941.1182451602, 1591193.8167312122)
#     l=0  Bisect at B = 343 with S = 1589452.178280405
#     l=0      B: 348 <- 356    shrinking 356 -> 348
#     l=0      B: 348 <- 356    B=348  niter:     1  count:    0  breaks:  0  min_S: 1590299.4  max_S: 1590723.0  S: 1590299.4  ΔS:     -423.656  moves:    17
#     l=0      B: 348 <- 356    B=348  niter:     2  count:    0  breaks:  0  min_S: 1589880.7  max_S: 1590723.0  S: 1589880.7  ΔS:     -418.709  moves:    12
#     l=0      B: 348 <- 356    B=348  niter:     3  count:    0  breaks:  0  min_S: 1589636.8  max_S: 1590723.0  S: 1589636.8  ΔS:     -243.848  moves:    10
#     l=0      B: 348 <- 356    B=348  niter:     4  count:    0  breaks:  0  min_S: 1589122.9  max_S: 1590723.0  S: 1589122.9  ΔS:     -513.967  moves:    15
#     l=0      B: 348 <- 356    B=348  niter:     5  count:    0  breaks:  0  min_S: 1588842.1  max_S: 1590723.0  S: 1588842.1  ΔS:     -280.790  moves:    12
#     l=0      B: 348 <- 356    B=348  niter:     6  count:    1  breaks:  1  min_S: 1588842.1  max_S: 1590723.0  S: 1588732.7  ΔS:     -109.391  moves:    12
#     l=0  Current bracket: (335, 343, 356) (1589941.1182451602, 1589452.178280405, 1591193.8167312122)
#     l=0  Bisect at B = 348 with S = 1588732.690092066
#     l=0      B: 351 <- 356    shrinking 356 -> 351
#     l=0      B: 351 <- 356    B=351  niter:     1  count:    1  breaks:  1  min_S: 1590172.8  max_S: 1590172.8  S: 1590139.7  ΔS:     -33.1460  moves:     6
#     l=0  Current bracket: (343, 348, 356) (1589452.178280405, 1588732.6900920663, 1591193.8167312122)
#     l=0  Bisect at B = 351 with S = 1590139.685165483
#     l=0      B: 345 <- 348    shrinking 348 -> 345
#     l=0      B: 345 <- 348    B=345  niter:     1  count:    1  breaks:  1  min_S: 1588168.9  max_S: 1588168.9  S: 1588094.3  ΔS:     -74.6186  moves:    10
#     l=0  Current bracket: (343, 348, 351) (1589452.178280405, 1588732.6900920663, 1590139.6851654833)
#     l=0  Bisect at B = 345 with S = 1588094.29544641
#     l=0      B: 346 <- 348    shrinking 348 -> 346
#     l=0      B: 346 <- 348    B=346  niter:     1  count:    0  breaks:  0  min_S: 1588021.4  max_S: 1588259.5  S: 1588021.4  ΔS:     -238.096  moves:     6
#     l=0      B: 346 <- 348    B=346  niter:     2  count:    0  breaks:  0  min_S: 1587792.8  max_S: 1588259.5  S: 1587792.8  ΔS:     -228.559  moves:    10
#     l=0      B: 346 <- 348    B=346  niter:     3  count:    0  breaks:  0  min_S: 1587623.5  max_S: 1588259.5  S: 1587623.5  ΔS:     -169.329  moves:    12
#     l=0      B: 346 <- 348    B=346  niter:     4  count:    0  breaks:  0  min_S: 1587426.0  max_S: 1588259.5  S: 1587426.0  ΔS:     -197.480  moves:     9
#     l=0      B: 346 <- 348    B=346  niter:     5  count:    1  breaks:  1  min_S: 1587426.0  max_S: 1588259.5  S: 1587351.0  ΔS:     -75.0525  moves:     7
#     l=0  Current bracket: (343, 345, 348) (1589452.178280405, 1588094.2954464103, 1588732.6900920663)
#     l=0  Bisect at B = 346 with S = 1587350.973413895
#     l=0      B: 347 <- 348    shrinking 348 -> 347
#     l=0      B: 347 <- 348    B=347  niter:     1  count:    0  breaks:  0  min_S: 1588171.2  max_S: 1588405.0  S: 1588171.2  ΔS:     -233.771  moves:    10
#     l=0      B: 347 <- 348    B=347  niter:     2  count:    0  breaks:  0  min_S: 1587924.3  max_S: 1588405.0  S: 1587924.3  ΔS:     -246.943  moves:    14
#     l=0      B: 347 <- 348    B=347  niter:     3  count:    0  breaks:  0  min_S: 1587686.2  max_S: 1588405.0  S: 1587686.2  ΔS:     -238.080  moves:     9
#     l=0      B: 347 <- 348    B=347  niter:     4  count:    1  breaks:  1  min_S: 1587686.2  max_S: 1588405.0  S: 1587546.8  ΔS:     -139.373  moves:     5
#     l=0  Current bracket: (345, 346, 348) (1588094.2954464103, 1587350.973413895, 1588732.6900920663)
#     l=0  Bisect at B = 347 with S = 1587546.79765792
#     l=0  Current bracket: (345, 346, 347) (1588094.2954464103, 1587350.973413895, 1587546.79765792)
#     l=0  Bisect at B = 345 with S = 1588094.29544641
#     l=0  Best result: B = 346, S = 1587350.973413895
# level 0 : rejected replacement (2246, 326) -> (2246, 346) , dS: 7008.8763392705005

# %%
state = model.state

# %% [markdown]
# # Plotting the result
#
# The output shows the (hierarchical) community structure in the word-document network as inferred by the stochastic block model:
#
# - document-nodes are on the left
# - word-nodes are on the right
# - different colors correspond to the different groups
#
# The result is a grouping of nodes into groups on multiple levels in the hierarchy:
#
# - on the uppermost level, each node belongs to the same group (square in the middle)
# - on the next-lower level, we split the network into two groups: the word-nodes and the document-nodes (blue sqaures to the left and right, respectively). This is a trivial structure due to the bipartite character of the network.
# - only next lower levels constitute a non-trivial structure: We now further divide nodes into smaller groups (document-nodes into document-groups on the left and word-nodes into word-groups on the right)

# %%
model.plot(nedges=1000)

# %%
state.draw(layout='bipartite', output='bipartite_overlap.png')
#state.draw(output='circular_overlap.png')

# %% [markdown]
# # The basics

# %% [markdown]
# ## Topics
# For each word-group on a given level in the hierarchy, we retrieve the $n$ most common words in each group -- these are the topics!

# %%
l=2

# %%
model.topics(l=l,n=200)

# %%
topic_lenghts = []
for topic in model.topics(l=l,n=2000):
    topic_lenghts.append(len(model.topics(l=l,n=2000)[topic]))
    
fig=plt.figure()
plt.hist(topic_lenghts, histtype='step', bins=11, lw=2)
plt.xlabel("topic size (# genes)", fontsize=16)
plt.ylabel("# topic of that size", fontsize=16)
plt.show()
fig.savefig("topic_size_%d.png"%l)

# %%
for ensg in model.topics(l=l,n=200)[4]:
    print(ensg[0])

# %% [markdown]
# ### DAVID compatible format

# %%
model.print_topics(l=l, format='tsv')

# %% [markdown]
# ## Topic-distribution in each document
# Which topics contribute to each document?

# %%
## select a document (by its index)
i_doc = 814
print(model.documents[i_doc])
## get a list of tuples (topic-index, probability)
#model.topicdist(i_doc,l=0)

# %%
data = [el[1] for el in model.topicdist(i_doc,l=l)]
labels = [el[0]+1 for el in model.topicdist(i_doc,l=l)]
fig=plt.figure()
plt.pie(data, labels=labels)
plt.title("Topic distribution: %s"%model.documents[i_doc])
plt.show()
fig.savefig("topic_distr_%s.png"%model.documents[i_doc])

# %% [markdown]
# # Extra: Clustering of documents - for free.
# The stochastic block models clusters the documents into groups.
# We do not need to run an additional clustering to obtain this grouping.

# %%
model.clusters(l=l,n=500)

# %% [markdown]
# Application -- Finding similar articles:
#
# For a query-article, we return all articles from the same group

# %%
## select a document (index)
i_doc = 2
print(i_doc,model.documents[i_doc])
## find all articles from the same group
## print: (doc-index, doc-title)
for file in model.clusters_query(i_doc,l=l):
    print(file[1],",")

# %% [markdown]
# # More technical: Group membership
# In the stochastic block model, word (-nodes) and document (-nodes) are clustered into different groups.
#
# The group membership can be represented by the conditional probability $P(\text{group}\, |\, \text{node})$. Since words and documents belong to different groups (the word-document network is bipartite) we can show separately:
#
# - P(bd | d), the probability of document $d$ to belong to document group $bd$
# - P(bw | w), the probability of word $w$ to belong to word group $bw$.

# %%
l=l
p_td_d,p_tw_w = model.group_membership(l=l)
fig = plt.figure(figsize=(15,4))
plt.subplot(121)
plt.imshow(p_td_d,origin='lower',aspect='auto',interpolation='none')
plt.title(r'Document group membership $P(bd | d)$')
plt.xlabel('Document d (index)')
plt.ylabel('Document group, bd')
plt.colorbar()

plt.subplot(122)
plt.imshow(p_tw_w,origin='lower',aspect='auto',interpolation='none')
plt.title(r'Word group membership $P(bw | w)$')
plt.xlabel('Word w (index)')
plt.ylabel('Word group, bw')
plt.colorbar()
plt.show()

# %%
fig.savefig("group_membership_%d.pdf"%l)
fig.savefig("group_membership_%d.png"%l)

# %%
overlaplenghts=[]
overlap_index = []
for i,el in enumerate(p_tw_w.T):
    mixture_size = len(np.nonzero(el)[0])
    overlaplenghts.append(mixture_size)
    if mixture_size>1:
        overlap_index.append(i)

# %%
fig=plt.figure()
plt.title("How many topics in a single gene")
plt.xlabel("# topic")
plt.ylabel("genes with that number of topics")
plt.hist(overlaplenghts, histtype='step', lw=2, range=(-0.5,5.5), bins=6)
plt.show()
fig.savefig("overlap_size_%d.png"%l)

# %%
gene=300
for gene in overlap_index[:10]:
    fig=plt.figure()
    plt.title("Topic distribution of a single gene: %s"%model.words[gene])
    plt.xlabel("topic tw")
    plt.ylabel("probability")
    plt.ylim((0,1.1))
    plt.plot(p_tw_w.T[gene])
    plt.show()
    fig.savefig("distribution_single_gene_%s.png"%model.words[gene])

# %% [markdown]
# ## overlapping genes

# %%
#get genes overlapping
overlappinggenes = []
for i,el in enumerate(p_tw_w.T):
    if(len(np.nonzero(el)[0])>1):
        overlappinggenes.append(model.words[i])

# %%
for g in overlappinggenes:
    print(g)

# %% [markdown]
# # state analysis

# %%
state = model.state

# %%
for level in state.get_levels():
    e=level.get_matrix()
    plt.matshow(e.todense())
    plt.savefig("mat_%d.png"%l)

# %%
for i in range(len(state.get_levels())-2)[::-1]:
    print("doing %d"%i)
    model.print_topics(l=i)
    plot_topic_dist(i)
    model.print_topics(l=i, format='tsv')

# %%
model.print_summary()

# %%
import pandas as pd
df = pd.DataFrame(data=model.words)
df.to_csv("background.txt", index=False, header=False)

# %%
print(len(model.words))
print(len(model.documents))

# %% [markdown]
# ### topicdist

# %%
def plot_topic_dist(l):
    groups = model.groups[l]
    p_w_tw = groups['p_w_tw']
    fig=plt.figure(figsize=(12,10))
    plt.imshow(p_w_tw,origin='lower',aspect='auto',interpolation='none')
    plt.title(r'Word group membership $P(w | tw)$')
    plt.xlabel('Topic, tw')
    plt.ylabel('Word w (index)')
    plt.colorbar()
    fig.savefig("p_w_tw_%d.png"%l)
    p_tw_d = groups['p_tw_d']
    fig=plt.figure(figsize=(12,10))
    plt.imshow(p_tw_d,origin='lower',aspect='auto',interpolation='none')
    plt.title(r'Word group membership $P(tw | d)$')
    plt.xlabel('Document (index)')
    plt.ylabel('Topic, tw')
    plt.colorbar()
    fig.savefig("p_tw_d_%d.png"%l)

# %%
for i in range(len(state.get_levels())-2)[::-1]:
    plot_topic_dist(i)
    model.print_topics(l=l, format='tsv')

# %%
topic=2
fig=plt.figure()
plt.title("Topic%d composition"%topic)
plt.xlabel("word w")
plt.ylabel("probability")
plt.plot(p_w_tw.T[topic])
plt.show()
fig.savefig("Topic%d_composition.png"%topic)

# %%
doc=12
title = model.documents[doc]
fig=plt.figure()
plt.title("Topic distribution of sample: %s"%title)
plt.xlabel("topic tw")
plt.ylabel("probability")
plt.plot(p_tw_d.T[doc])
plt.show()
fig.savefig("distribution_single_sample_%d.png"%doc)
